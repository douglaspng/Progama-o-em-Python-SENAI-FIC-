# %% [markdown]
# # DICIONÁRIOS

# %%
# EXEMPLO 01


almoco = {'comida': 'Lanche', 'bebida': 'Água', 'sobremesa': 'Pudim'}
print(type(almoco))
print(almoco)
print(almoco['comida'])
# Out:
# <class 'dict'>
# {'comida': 'Lanche', 'bebida': 'Água', 'sobremesa': 'Pudim'}
# Lanche

# %%
# EXEMPLO API MOEDA


d = {"BTCUSD":{"code":"BTC","codein":"USD","name":"Bitcoin/Dólar Americano","high":"68519.9921875","low":"67475.1171875","varBid":"-238.6975","pctChange":"-0.350383","bid":"67885.99","ask":"67886","timestamp":"1772904127","create_date":"2026-03-07 14:22:07"}}


print(d['BTCUSD']['high'])
# Out:
# 68519.9921875

# %%
# EXEMPLO 01 v2

almoco = {'comida': 'Lanche', 'bebida': 'Água', 'sobremesa': ['Pudim', 'Mousse']}
print(almoco['sobremesa'][1])
# Out:
# Mousse

# %%
# EXEMPLO 02 ITENS (FORMATO JSON)


almoco = {
    'comida': 'Lanche',
    'bebida': 'Água',
    'sobremesa': 'Pudim'
    }


print(type(almoco.items()))
# Out:
# <class 'dict_items'>

# %%
# EXEMPLO 3 CHAVES

print(almoco.keys())
# Out:
# dict_keys(['comida', 'bebida', 'sobremesa'])

# %%
# EXEMPLO 3 vALORES

print(almoco.values())
# Out:
# dict_values(['Lanche', 'Água', 'Pudim'])

# %%
# EXEMPLO 05


for chave, valor in almoco.items():
    print(f"{chave:12} | {valor:>12}")
# Out:
# comida       |       Lanche
# bebida       |         Água
# sobremesa    |        Pudim

# %%
# EXEMPLO 06 (Alterar valores do dicionário)


almoco['bebida'] = 'Suco de laranja'
for chave, valor in almoco.items():
    print(f"{chave:12} | {valor:>15}")
# Out:
# comida       |          Lanche
# bebida       | Suco de laranja
# sobremesa    |           Pudim

# %%
# EXEMPLO 07 (Remover valores do dicionário)


del almoco['sobremesa']
for chave, valor in almoco.items():
    print(f"{chave:12} | {valor:12}")
# Out:
# comida       | Lanche
# bebida       | Água

# %% [markdown]
# # EXEMPLO 09
#
#
# estado = {}
# brasil = []
#
#
# for _ in range(2):
#     estado['uf']    = input("Digite a unidade federativa: ")
#     estado['sigla'] = input("Digite a sigla do estado: ")
#     brasil.append(estado.copy())
#
#
# print(brasil)
# print(brasil[0]['sigla'])
#
#
# print(estado)

# %%
# EXEMPLO 10


for estado in brasil:
    for valor in estado.values():
        print(valor)

# %%
# EXEMPLO 10

print(estado)
# Out:
# {'uf': 'Espirito Santo', 'sigla': 'ES'}

# %%
# EXEMPLO 11


for estado in brasil:
        print(estado['uf'], estado['sigla'], sep=' | ')
# Out:
# São Palo | SP
# Espirito Santo | ES

# %% [markdown]
# # DESAFIOS

# %%
# DESAFIO 01
"""
Dada a lista 'almoco', mostre a comida de Catarina.
"""
almoco = [
    {'nome': 'Leandro', 'comida': 'Lanche', 'bebida': 'Suco de Laranja'},
    {'nome': 'Celia', 'comida': 'Lasanha', 'bebida': 'Suco de uva'},
    {'nome': 'Catarina', 'comida': 'Pizza', 'bebida': 'Coca-Cola'}
]

print(almoco[2]['comida'])
# Out:
# Pizza

# %%
# DESAFIO 02
"""
Com a lista do DESAFIO anterior, exiba uma lista com o nome da pessoa e o que ela come e bebe.
"""
almoco = [
    {'nome': 'Leandro', 'comida': 'Lanche', 'bebida': 'Suco de Laranja'},
    {'nome': 'Celia', 'comida': 'Lasanha', 'bebida': 'Suco de uva'},
    {'nome': 'Catarina', 'comida': 'Pizza', 'bebida': 'Coca-Cola'}
]

for i in range(len(almoco)):
    print(f"{almoco[i]['nome']} come {almoco[i]['comida']} e bebe {almoco[i]['bebida']}")
# Out:
# Leandro come Lanche e bebe Suco de Laranja
# Celia come Lasanha e bebe Suco de uva
# Catarina come Pizza e bebe Coca-Cola

# %%
# DESAFIO 03
"""
Faça  um programa que leia o nome e média de um aluno, guardando também a
situação em um dicionário.
(Abaixo de 5: Reprovado | entre 5 e 6,9: Exame | 7: acima Aprovado)
No final mostre o conteúdo da estrutura na tela.

"""

aluno = {'nome': input("Digite o nome do aluno "), 'nota': int(input("Digite a nota do aluno "))}


if aluno['nota'] >= 7 :
    aluno['situação'] = ("Parabéns, você foi aprovado")

elif aluno['nota'] >= 5 and aluno['nota'] <= 6.9:
    aluno['situação'] = ("Você está de recuperação")

elif aluno['nota'] < 5:
    aluno['situação'] = ("Você está reprovado")

else:
    print("\nNota inválida")

print(aluno)
print(aluno['situação'])
# Out:
# Digite o nome do aluno Henrique
# Digite a nota do aluno 9
# {'nome': 'Henrique', 'nota': 9, 'situação': 'Parabéns, você foi aprovado'}
# Parabéns, você foi aprovado
