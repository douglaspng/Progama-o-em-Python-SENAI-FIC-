# %% [markdown]
# # CONDICIONAIS DE IF ELIF ELSE

# %%
# ESTRUTURAS CONDICIONAIS
"""
OPERADORES RELACIONAIS (OU DE COMPARAÇÃO)


>  MAIOR
<  MENOR
>= MAIOR OU IGUAL
<= MENOR OU IGUAL
== IGUAL
!= DIFERENTE


OPERADORES LÓGICOS (CONECTORES LÓGICOS)


and | or | not | in | not in
"""
# Out:
# '\nOPERADORES RELACIONAIS (OU DE COMPARAÇÃO)\n\n\n>  MAIOR\n<  MENOR\n>= MAIOR OU IGUAL\n<= MENOR OU IGUAL\n== IGUAL\n!= DIFERENTE\n\n\nOPERADORES LÓGICOS (CONECTORES LÓGICOS)\n\n\nand | or | not | in | not in\n'

# %%
# BLOCO if


x = 10
if x > 5:
    print("É maior que 5")
    if x < 8:
        print("Também é menor que 8")
if x == 10:
    print("X vale 10")
# Out:
# É maior que 5
# X vale 10

# %%
# BLOCO if else


y = 8
if y != 8:
    print("É diferente de 8")
else:
    print("É igual a 8")
# Out:
# É igual a 8

# %%
# BLOCO if elif else

z = 31
if z <= 10:
    print("Frio")
elif z <= 20:
    print("Morno")
elif z <= 30:
    print("Quente")
else:
    print("Muito quente")
# Out:
# Muito quente

# %%
# BLOCO COM and


n = 54.999
if n >= 55 and n <= 70:
    print("Valor ideal 👍")
else:
    print("Faça outros exames, você está dodói 👎")
# Out:
# Faça outros exames, você está dodói 👎

# %%
# BLOCO COM or


casado = False
filhos = False


if casado or filhos:
    print("Corre!!!!")
else:
    print("Livre para casar...")
# Out:
# Livre para casar...

# %%
# BLOCO COM in


escola = "SENAI Ary Torres"
min = escola.lower()

if 'ary' in min:
    print("Tem Ary no nome!")
else:
    print("Não tem Ary no nome!")
print('\n', escola)
# Out:
# Tem Ary no nome!
#
#  SENAI Ary Torres

# %%
# BLOCO COM not in


escola = "SENAI Ary Torres"


if 'Ary' not in escola:
    print("Não tem Ary no nome!")
else:
    print("Tem Ary no nome!")
# Out:
# Tem Ary no nome!

# %%
# NÃO UTILIZAR ESSA ESTRUTURA!!!!!!


a = 3
b = 2
c = 1


if a>b>c: # if a>b and b>c:
    print("A é maior")
# Out:
# A é maior

# %% [markdown]
# # DESAFIOS

# %%
# DESAFIO 01
"""
Crie um programa que leia o nome de um bairro e diga se
ele começa ou não com o nome Santo.
"""

nome_bairro = input("Digite o nome do seu bairro ").split()[0]
min = nome_bairro.lower()

if 'santo' == min:
    print("\nSeu bairro começa com Santos")
else :
    print("\nSeu bairro não começa com Santos")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3625716227.py in <cell line: 0>()
#       5 """
#       6
# ----> 7 nome_bairro = input("Digite o nome do seu bairro ").split()[0]
#       8 min = nome_bairro.lower()
#       9
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
# DESAFIO 02
"""
Crie um programa que leia o nome de uma pessoa e diga se ela
tem "Silva" no nome.
"""

nome = input("Digite o seu nome completo ").lower().split()

if 'silva' == nome:
    print("\nSeu nome possui a palavra Silva")
else :
    print("\nSeu nome não possui a palavra Silva")

# %%
# DESAFIO 02.1

nome = input("Digite o seu nome: \033[3m ").lower()

if 'silva' == nome:
    print("\nSeu nome possui a palavra Silva")
else :
    print("\n\033[0mSeu nome não possui a palavra Silva")

# %%
"""
Crie um programa que leia uma frase qualquer e diga se ela
é um palíndromo, exemplo:
APOS A SOPA
A SACADA DA CASA
A TORRE DA DERROTA
SOCORRAM ME SUBI NO ONIBUS EM MARROCOS
"""

# %%
palindromo = input("Digite uma palavra para saber se ela é um palíndromo: ").lower().replace(' ', '')
inver = palindromo[::-1]

if palindromo == inver:
    print("\nSua palavra é um palíndromo")
else:
    print("\nIsso não é um palíndromo")

# %%
# DESAFIO 04
"""
Escreva um programa que faça o computador sortear um
número inteiro entre 1 e 3 e peça para o usuário tentar
descobrir qual foi o número escolhido pelo computador.


O programa deverá escrever na tela se o usuário venceu ou
perdeu.


Biblioteca necessária:
import random
random.randint(0, 1000)
"""

import random # Ele importa a biblioteca de sortear
from google.colab import output # Biblioteca do google para limpar o input

numero = float(input("Adivinhe um número de 1 a 3, se você acertar vai ganhar uma estrela: "))

aleatorio = random.randint(1, 3)

output.clear()

if numero > 3 or numero < 1:
    print("Você não sabe ler?")
else:
    print(f"E o número sorteado foi esse {aleatorio}")

if numero == aleatorio:
    print("\nParabéns, aqui está sua estrela 🌟")
else:
    print("\nVocê \033[31mfalhou\033[0m! Tente novamente...")

# %%
# OPERADOR TERNÁRIO

import random # Ele importa a biblioteca de sortear
from google.colab import output # Biblioteca do google para limpar o input

numero = float(input("Adivinhe um número de 1 a 3, se você acertar vai ganhar uma estrela: "))

aleatorio = random.randint(1, 3)

output.clear()

print("Você não sabe ler?"if numero > 3 or numero < 1 else f"E o número sorteado foi esse {aleatorio}")

print("\nParabéns, aqui está sua estrela 🌟" if numero == aleatorio else "\nVocê \033[31mfalhou\033[0m! Tente novamente...")

# %%
# EXEMPLO 01

x = 5
var = x**2 if x == 5 else x**3
print(var)

# %%
# EXEMPLO 02

nome = 'Leandro'
var = "É um nome bonito!" if nome == 'Leandro' else 'Um outro nome'
print(var)

# %%
# DESAFIO 05
"""
Escreva um programa que leia a velocidade de um carro.
Se ele ultrapassar 80 km/h, mostre uma mensagem dizendo que
ele foi multado.
A multa custará R$ 7,00 por cada km acima do limite.
"""

import random

print("Carro passando... \033[33m__________🚗_______ \033[0m")

velocidade_carro = random.randint(25, 100)

print(f"\n\n-O radar de velocidade constou que o carro passou a {velocidade_carro}kmh ")

if velocidade_carro > 80:
    print("\n-A avenida é permitida no máximo 80kmh, o carro levará uma multa de excesso de velocidade")
    print(f"\nValor da multa R${float((velocidade_carro - 80)*7):02}")
elif velocidade_carro < 40:
    print("\n-Ele passou abaixo da metade da velocidade da via, ele levará uma multa por trafegar em velocidade muito reduzida")
    print(f"\nValor da multa R${float((velocidade_carro - 40)*-7):02}")
else:
    print("\n-Ele está dentro dos limites, que orgulho!")
# Out:
# Carro passando... __________🚗_______
#
#
# -O radar de velocidade constou que o carro passou a 31kmh
#
# -Ele passou abaixo da metade da velocidade da via, ele levará uma multa por trafegar em velocidade muito reduzida
#
# Valor da multa R$63.0

# %%
# DESAFIO 06
"""
Crie um programa que leia um número inteiro e mostre na tela
se ele é PAR ou ÍMPAR.
"""

#                              NÃO CONSEGUI FAZER

numero = float(input("Escreva um número para saber se ele é par ou impar: "))

if numero %2 == 0:
    print("\nEle é par")
else:
    print("\nEle é Ímpar")
# Out:
# Escreva um número para saber se ele é par ou impar 2
#
# Ele é par

# %%
# DESAFIO 07
"""
Escreva um programa que pergunte o salário de um funcionário
e calcule o valor do seu aumento.
Para salários superiores a R$ 1.250,00, calcule um aumento de
10%.
Para salários inferiores ou iguais, o aumento é de 15%.
"""

from google.colab import output

salario = float(input("Qual é o seu salário, para saber seu aumento salarial? ""\n1R$"))

output.clear()

if salario > 1250 and salario != 1250:
    print(f"Seu aumento salarial é 10%, então seu salário ficou R${salario * (10/100) + salario:,.2f} ") # Os parênteses não possuem uma papel signficante, são apenas para delimitar uma porcentagem
else:
    print(f"Seu aumento salarial foi de 15%, então seu salário ficou em R${salario * (15/100) + salario:,.2f} ")
# Out:
# Seu aumento salarial é 10%, então seu salário ficou R$11,000.00

# %%
# DESAFIO 08
"""
Desenvolva um programa que pergunte a distância de uma
viagem em km. Calcule o preço da passagem cobrando R$
0,50 por Km para viagens de até 200 Km e R$ 0,45 para
viagens mais longas.
"""

from google.colab import output

distancia_km = float(input("Sabemos que você vai viajar, para calcular o preço da sua viagem, qual será a distância em kilômetros para seu destino? \n\n"))

output.clear()

if distancia_km <= 200:
    print(f"O preço da sua passagem será de RS{distancia_km *0.5:,.2f}")
else:
    print(f"O preço da sua passagem vai ser de R${distancia_km *0.45:,.2f} ")

resposta_compra = input("O Senhor deseja conclui a compra? ").lower()

if resposta_compra == 'sim':
    print("\nCompra finalizada com \033[32msucesso\033[0m!")
else:
    print("\nCompra cancelada.")
# Out:
# O preço da sua passagem vai ser de R$112.50
# O Senhor deseja conclui a compra? sim
# Compra finalizada com sucesso!

# %%
# DESAFIO 09
"""
Escreva um programa para aprovar um empréstimo bancário
para a compra de uma casa. O programa vai perguntar o valor
da casa, o salário do comprador e em quantos anos ele vai
pagar.


Calcule o valor da prestação mensal, sabendo que ela não
pode exceder 30% do salário ou então o empréstimo será
negado.
"""

valor = float(input("Digite o valor do imóvel: "))
salario = float(input("Digite o valor do salário: "))
meses = int(input("Digite a quantidade de anos: "))*12
parcela = valor/meses
salario_30 = salario*0.3

if parcela > salario_30:
    print("Empréstimo negado")
    print(f"Valor máximo de parcela: R${salario_30:,.2f}")
    print(f"Parcela simulada: R${parcela:,.2f}")
else:
    print("Empréstimo aprovado")
    print(f"Valor da parcela: R${parcela:,.2f}")
# Out:
# Digite o valor do imóvel: 2
# Digite o valor do salário: 2
# Digite a quantidade de anos: 2
# Empréstimo aprovado
# Parcela simulada: R$0.08

# %%
# DESAFIO 10
"""
Faça um programa que leia o ano de nascimento de um jovem
e informe, de acordo com sua idade:


Se ele ainda vai se alistar ao serviço militar
Se é a hora de se alistar
Se já passou o tempo do alistamento


Seu programa também deverá mostrar o tempo que falta ou
que passou do prazo.
"""
from google.colab import output

ano = float(input("Qual é seu ano de nascimento? \n\n"))
idade = 2026-ano

output.clear()

if idade == 18:
    print("\nVocê precisa se alistar para o exército")
elif idade > 18:
    print("\nJá passou da idade para se alistar!!")
    print(f"\nEra para você ter se alistado a {idade - 18:.0f} anos.")
else:
    print("\nRelaaaaaxa, ainda falta tempo para você se alistar")
    print(f"\nFaltam {18-idade:.0f} ano(s).")
# Out:
# Relaaaaaxa, ainda falta tempo para você se alistar
#
# Faltam 22 ano(s).

# %%
# DESAFIO 11
"""
Crie um programa que leia duas notas entre 0 a 10 de um aluno
e calcule sua média, mostrando uma mensagem no final, de
acordo com a média atingida.


Média abaixo de 5.0: REPROVADO
Média entre 5.0 a 6.9: RECUPERAÇÃO
Média igual ou superior a 7.0: APROVADO
"""
from google.colab import output

nota1 = float(input("Digite a sua primária \n\n"))
nota2 = float(input("Digite a sua secundária \n"))

aprovado = (nota1 + nota2)/2

output.clear()

if nota1 > 10 or nota1 < 0 or nota2 > 10 or nota2 < 0:
    print("Nota inválida.")
elif aprovado >= 7:
    print("\nMeus parabéns, você foi aprovado!!")
elif aprovado == 6.9 or aprovado >= 5:
    print("\nFoi quase, você está de recuperação.")

else:
    print("\nQue decepção, você foi reprovado...")
# Out:
# Foi quase, você está de recuperação.

# %%
# DESAFIO 11 v2


nota1 = float(input("Digite a 1ª nota: "))
nota2 = float(input("Digite a 2ª nota: "))


if nota1 < 0 or nota1 > 10 or nota2 < 0 or nota2 > 10:
    print("\n\033[31mAs notas devem ser entre 0 e 10...\033[0m")
else:
    media = (nota1+nota2)/2


    if media < 5:
        print(f"\nREPROVADO com média: {media:.1f}")
    elif media < 7:
        print(f"\nRECUPERAÇÃO com média: {media:.1f}")
    else:
        print(f"\nAPROVADO com média: {media:.1f}")

# %%
# DESAFIO 12
"""
Desenvolva um programa que leia o comprimento de três retas
e diga ao usuário se elas podem ou não formar um triângulo.
Condições Necessárias:
a + b > c
a + c > b
b + c > a
"""

valor_a = float(input("Digite o primeiro valor da reta do seu triângulo: "))
valor_b = float(input("Digite o segundo valor da reta do seu triângulo: "))
valor_c = float(input("Digite o terceiro valor da reta do seu triângulo: "))

if valor_a + valor_b > valor_c and valor_b + valor_c > valor_a and valor_a + valor_c > valor_b:
    print("\nSeu triângulo está na proporção correta!")
else:
    print("\nEle está com as medidas erradas.")
# Out:
# Digite o primeiro valor da reta do seu triângulo: 4
# Digite o segundo valor da reta do seu triângulo: 5
# Digite o terceiro valor da reta do seu triângulo: 6
#
# Seu triângulo está na proporção correta!

# %%
# DESAFIO 13
"""
Escreva um programa que leia dois números inteiros e
compare- os, mostrando na tela uma mensagem:


O primeiro valor é maior
O segundo valor é maior
Não existe valor maior, os dois são iguais
"""

valor_1 = input("Digite um valor, que iremos considerar o primário: ")
valor_2 = input("\nAgora digite outro valor, iremos considerar esse como secundário: ")

if valor_1 > valor_2:
    print("\nPor mais que você já saiba, o primeiro valor, é maior do que o segundo ")
elif valor_2 > valor_1:
    print("\nO valor secundário é maior do que o primário. ")
else:
    print("\nOlha só, os dois valores são iguais! ")
# Out:
# Digite um valor, que iremos considerar o primário: 11
#
# Agora digite outro valor, iremos considerar esse como secundário: 11
#
# Olha só, os dois valores são iguais!

# %%
# DESAFIO 14
"""
Faça um programa que leia três números e mostre qual é o
maior e qual é o menor.
"""

valor_1 = float(input("Digite um valor, que iremos considerar o primário: "))
valor_2 = float(input("\nAgora digite outro valor, iremos considerar esse como secundário: "))
valor_3 = float(input("\nNovamente digite outro valor, iremos considerar esse como terceário: "))

if valor_1 > valor_2 and valor_1 > valor_3:
    print("\nO número maior é o primário!!")
elif valor_2 > valor_1 and valor_2 > valor_3:
    print("\nO número maior é o secundário!!")
else:
    print("\nO número maior é o terceário!!")

if valor_1 < valor_2 and valor_1 < valor_3:
    print("\nO número menor é o primário!!")
elif valor_2 < valor_1 and valor_2 < valor_3:
    print("\nO número menor é o secundário!!")
else:
    print("\nO número menor é o terceário!!")
# Out:
# Digite um valor, que iremos considerar o primário: 4
#
# Agora digite outro valor, iremos considerar esse como secundário: 6
#
# Novamente digite outro valor, iremos considerar esse como terceário: 2
#
# O número maior é o secundário!!
#
# O número menor é o terceário!!

# %%
# DESAFIO 14.3

valor_1 = float(input("Digite um valor, que iremos considerar o primário: "))
valor_2 = float(input("\nAgora digite outro valor, iremos considerar esse como secundário: "))
valor_3 = float(input("\nNovamente digite outro valor, iremos considerar esse como terceário: "))

maior = max(valor_1, valor_2, valor_3)
menor = min3(valor_1, valor_2, valor_3)

print("\n Me mostre o maior número:", maior)
print("\n Me mostre o menor número.", menor)
# Out:
# Digite um valor, que iremos considerar o primário: 2
#
# Agora digite outro valor, iremos considerar esse como secundário:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2871526595.py in <cell line: 0>()
#       2
#       3 valor_1 = float(input("Digite um valor, que iremos considerar o primário: "))
# ----> 4 valor_2 = float(input("\nAgora digite outro valor, iremos considerar esse como secundário: "))
#       5 valor_3 = float(input("\nNovamente digite outro valor, iremos considerar esse como terceário: "))
#       6
#
# ValueError: could not convert string to float: ''

# %%
# DESAFIO 15
"""
Escreva um programa que leia um número inteiro e peça para o
usuário escolher qual será a base de conversão:


1 para binário bin()
2 para octal oct()
3 para hexadecimal hex()
"""

valor_1 = int(input("Escolha um número de sua preferência: "))

opcao_conversao = input("\nVocê gostaria de converter esse seu número para binário, octal ou hexadecimal? \n\n").lower()

if opcao_conversao == "binário":
    print(f"\nSeu núemro seria então {bin(valor_1)}. ")
elif opcao_conversao == "octal":
    print(f"\nAqui está seu número na forma octal {oct(valor_1)}.")
else:
    print(f"\nAqui está seu número na forma hexadecimal {hex(valor_1)}.")
# Out:
# Escolha um número de sua preferência: 2
#
# Você gostaria de converter esse seu número para binário, octal ou hexadecimal?
#
# 3
#
# Aqui está seu número na forma hexadecimal 0x2.

# %%
# DESAFIO 15
"""
Escreva um programa que leia um número inteiro e peça para o
usuário escolher qual será a base de conversão:


1 para binário bin()
2 para octal oct()
3 para hexadecimal hex()
"""

valor_1 = int(input("Escolha um número de sua preferência: "))
opcao_conversao = input("""\nVocê gostaria de converter esse seu número para binário, octal ou hexadecimal?
[1]
[2]
[3]
\n""").lower()

if opcao_conversao == "1":
    print(f"\nSeu núemro seria então {bin(valor_1)[2:]}. ")
elif opcao_conversao == "2":
    print(f"\nAqui está seu número na forma octal {oct(valor_1)[2:]}.")
else:
    print(f"\nAqui está seu número na forma hexadecimal {hex(valor_1)[2:]}.")
# Out:
# Escolha um número de sua preferência: 2
#
# Você gostaria de converter esse seu número para binário, octal ou hexadecimal?
# [1]
# [2]
# [3]
#
# 3
#
# Aqui está seu número na forma hexadecimal 0x2.
