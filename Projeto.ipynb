# %%
#TOTEM DE COMPRA DE UMA FÁBRICA
#Usei o sys para conseguir interromper o programa como se fosse um break

from google.colab import output
import sys

while True:
    try:
        cardapio = int(input("Bom dia! Gostaria de ver o cardápio? "
                            '\n[1] Para sim'
                            '\n[0] Encerrar o progama'
                            '\n'         ))
    except:
        print("Isso não é um número, tente novamente ")
    else:
        output.clear()
        break

if cardapio == 1:
    print("          PRATOS FEITOS\n"
            "\n[10] Parmegiana", '.'*20,'R$32.99'
            "\n[11] Bolonhesa", '.'*21,'R$32.99'
            "\n[12] Filé de Frango", '.'*16,'R$32.99'
            "\n[13] Contra Filé", '.'*19,'R$34.99'
            "\n[14] Linguiça Suína", '.'*16,'R$29.99'
            "\n[15] Strognoffe", '.'*20,'R$27.99'
            "\n[16] Carne de Panela Tradicional", '.'*3,'R$32.99'
            "\n[17] Almondêgas", '.'*20,'R$29.99'
            "\n[18] Macarrão com queijo", '.'*11,'R$32.99'
            "\n[19] Macarrão água e óleo", '.'*10,'R$22.99'
            "\n[20] Lasanha", '.'*23,'R$32.99')
else:
    sys.exit("Encerrando o programa por erro.")

while True:
    try:
        lanche_resposta = int(input("Selecione seu prato "))
    except:
        print("Selecione algum prato válido")
        continue
        output.clear()
    match lanche_resposta:
        case 10:
                print("Sua Parmegiana estará pronta em 20 ")
        case 11:
                print("Sua Bolonhesa estará pronta em 20 ")
        case 12:
                print("Seu Filé de Frango estará pronta em 20 ")
        case 13:
                print("Seu Contra Filé estará pronta em 20 ")
        case 14:
                print("Sua Linguiça Suína estará pronta em 20 ")
        case 15:
                print("Sua Strognoffe estará pronta em 20 ")
        case 16:
                print("Sua Carne de Panela Tradicional estará pronta em 20 ")
        case 17:
                print("Sua Almondêgas estará pronta em 20 ")
        case 18:
                print("Sua Macarrão com queijo estará pronta em 20 ")
        case 19:
                print("Sua Macarrão água e óleo estará pronta em 20 ")
        case 20:
                print("Sua Lasanha estará pronta em 20 ")

    print("Obrigado pela preferência")
    break
# Out:
#           PRATOS FEITOS
#
# [10] Parmegiana .................... R$32.99
# [11] Bolonhesa ..................... R$32.99
# [12] Filé de Frango ................ R$32.99
# [13] Contra Filé ................... R$34.99
# [14] Linguiça Suína ................ R$29.99
# [15] Strognoffe .................... R$27.99
# [16] Carne de Panela Tradicional ... R$32.99
# [17] Almondêgas .................... R$29.99
# [18] Macarrão com queijo ........... R$32.99
# [19] Macarrão água e óleo .......... R$22.99
# [20] Lasanha ....................... R$32.99
# Selecione seu prato 10
# Sua Parmegiana estará pronta em 20
# Obrigado pela preferência
